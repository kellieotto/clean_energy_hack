# %%
import pandas as pd
import string

# %%
board_data1 = pd.read_csv("../2020_board_data.csv")
board_data1.head()
board_data2 = pd.read_csv("../corp_boards_40_80.csv", header=None)
board_data2.columns = board_data1.columns
board_data2.head()
board_data = pd.concat([board_data1, board_data2], axis=0)

# %%
board_data.head()
# Out:
#                              Company  2020 Rating  Total Board  # of women  \
# 0                              3M CO          NaN           11           2
# 1                ABBOTT LABORATORIES          NaN           12           4
# 2                  ADOBE SYSTEMS INC          NaN           10           2
# 3                          AFLAC INC          NaN           14           3
# 4  AIR PRODUCTS & CHEMICALS INC /DE/          NaN            8           2
#
#   % of Women              Sector         State          City
# 0        18%         Industrials     Minnesota     ST. PAUL
# 1        33%          Healthcare      Illinois  ABBOTT PARK
# 2        20%          Technology    California     SAN JOSE
# 3        21%  Financial Services       Georgia     COLUMBUS
# 4        25%     Basic Materials  Pennsylvania    ALLENTOWN

# %%
board_data['Company_clean'] = board_data['Company'].str.lower()
board_data['Company_clean'] = board_data['Company_clean'].str.replace(" inc", "")
board_data['Company_clean'] = board_data['Company_clean'].str.replace(" inc.", "")
board_data['Company_clean'] = board_data['Company_clean'].str.replace(" co", "")
board_data['Company_clean'] = board_data['Company_clean'].str.replace(" corp", "")
board_data['Company_clean'] = board_data['Company_clean'].str.replace(" /de/", "")
board_data.head()
# Out:
#                              Company  2020 Rating  Total Board  # of women  \
# 0                              3M CO          NaN           11           2
# 1                ABBOTT LABORATORIES          NaN           12           4
# 2                  ADOBE SYSTEMS INC          NaN           10           2
# 3                          AFLAC INC          NaN           14           3
# 4  AIR PRODUCTS & CHEMICALS INC /DE/          NaN            8           2
#
#   % of Women              Sector         State          City  \
# 0        18%         Industrials     Minnesota     ST. PAUL
# 1        33%          Healthcare      Illinois  ABBOTT PARK
# 2        20%          Technology    California     SAN JOSE
# 3        21%  Financial Services       Georgia     COLUMBUS
# 4        25%     Basic Materials  Pennsylvania    ALLENTOWN
#
#               Company_clean
# 0                        3m
# 1       abbott laboratories
# 2             adobe systems
# 3                     aflac
# 4  air products & chemicals
